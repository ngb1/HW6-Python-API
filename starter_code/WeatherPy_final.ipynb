 'te anau', 'vostok', 'nassjo', 'beloha', 'sao francisco de assis', 'los llanos de aridane', 'kodiak', 'liwale', 'dzaoudzi', 'bodden town', 'katherine', 'honningsvag', 'boyolangu', 'porto walter', 'viedma', 'itarema', 'coquimbo', 'robertson', 'tumannyy', 'acajutla', 'belle glade', 'lebu', 'verkh-usugli', 'waconia', 'altay', 'ganta', 'mega', 'kapuskasing', 'obo', 'orichi', 'broome', 'noumea', 'luza', 'fevralsk', 'dubbo', 'nanlong', 'huejuquilla el alto', 'kitob', 'sibolga', 'teguldet', 'ambilobe', 'mehamn', 'grand river south east', 'oyama', 'vaasa', 'ancud', 'klyuchi', 'guerrero negro', 'san quintin', 'beringovskiy', 'comodoro rivadavia', 'lahijan', 'sao francisco', 'gazanjyk', 'pangnirtung', 'aklavik', 'phichit', 'tomatlan', 'mata', 'bejar', 'gat', 'khatanga', 'nouadhibou', 'kodinsk', 'hithadhoo', 'talaya', 'tommot', 'pisco', 'shimoda', 'cuamba', 'bulgan', 'turtas', 'faanui', 'pitimbu', 'miraflores', 'norman wells', 'bintulu', 'alice springs', 'san andres', 'along', 'sikandarabad', 'kudat', 'ahipara', 'kamaishi', 'todos santos', 'iringa', 'inirida', 'muriti', 'akyab', 'turukhansk', 'vaitupu', 'luena', 'shingu', 'avera', 'panama city', 'uzhur-4', 'pacific grove', 'erzin', 'viligili', 'banda aceh', 'trincomalee', 'dunedin', 'winslow', 'lolua', 'clyde river', 'macklin', 'ostrovnoy', 'iskateley', 'carhuamayo', 'amalapuram', 'flekkefjord', 'kyabram', 'soyo', 'husavik', 'touros', 'lazaro cardenas', 'putina', 'hay river', 'bethel', 'ka ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric" # for degF and mph, units must be either changed to "imperial" or converted manually as a calculated variable


# Build partial query URL
query_url = f'{url}appid={api_key}&units={units}&q='
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=36ad1341a12fbbc418a9724a013b4769&units=metric&q=

# %%
#testing requests
q2 = query_url + "arraial do cabo"
r2 = requests.get(q2).json()
print(r2['name'])
# Out:
# Arraial do Cabo

# %%
# formatting
print("-----------------------------")
print("Beginning Data Retrieval")
print("-----------------------------")

# creating empty lists to store data
city1 = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
temp = []
max_temp = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    response = requests.get(query_url + city).json()
    try:
        name = response['name']
        city1.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])

        print(f'Processing Record: {cities.index(city)+1} of {len(cities)} |  {name}')

    except (ValueError,KeyError):
        print("City not found. Skipping")

print("-----------------------------")
print("Data Retrieval Complete   ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record: 1 of 635 |  Saskylakh
# Processing Record: 2 of 635 |  Barao de Melgaco
# Processing Record: 3 of 635 |  Albany
# Processing Record: 4 of 635 |  Hamilton
# Processing Record: 5 of 635 |  Tuktoyaktuk
# Processing Record: 6 of 635 |  Abu Zabad
# Processing Record: 7 of 635 |  Butaritari
# Processing Record: 8 of 635 |  Tasiilaq
# Processing Record: 9 of 635 |  Tari
# Processing Record: 10 of 635 |  Atuona
# Processing Record: 11 of 635 |  Mount Isa
# Processing Record: 12 of 635 |  Rikitea
# Processing Record: 13 of 635 |  Ponta do Sol
# Processing Record: 14 of 635 |  Cape Town
# Processing Record: 586 of 635 |  Rantauprapat
# Processing Record: 587 of 635 |  Sao Joao da Barra
# Processing Record: 588 of 635 |  Nemuro
# Processing Record: 589 of 635 |  LUGOBA
# Processing Record: 590 of 635 |  Calderitas
# Processing Record: 591 of 635 |  Puerto Baquerizo Moreno
# Processing Record: 592 of 635 |  Takoradi
# Processing Record: 593 of 635 |  Marsaxlokk
# Processing Record: 594 of 635 |  Kupang
# City not found. Skipping
# Processing Record: 596 of 635 |  Carolina
# Processing Record: 597 of 635 |  Umm Lajj
# Processing Record: 598 of 635 |  Den Helder
# City not found. Skipping
# Processing Record: 600 of 635 |  Baglung
# City not found. Skipping
# Processing Record: 602 of 635 |  Ushtobe
# Processing Record: 603 of 635 |  Yanam
# Processing Record: 604 of 635 |  Homer
# Processing Record: 605 of 635 |  Harper
# Processing Record: 606 of 635 |  Berga
# Processing Record: 607 of 635 |  Praia da Vitoria
# Processing Record: 608 of 635 |  Samsun
# Processing Record: 609 of 635 |  Okhotsk
# Processing Record: 610 of 635 |  Arlit
# City not found. Skipping
# Processing Record: 612 of 635 |  Kochki
# Processing Record: 613 of 635 |  Aksarka
# Processing Record: 614 of 635 |  Soto
# Processing Record: 615 of 635 |  Galveston
# Processing Record: 616 of 635 |  Battle Creek
# City not found. Skipping
# Processing Record: 618 of 635 |  Gazojak
# Processing Record: 619 of 635 |  Annau
# Processing Record: 620 of 635 |  Santa Maria
# Processing Record: 621 of 635 |  Rio Gallegos
# Processing Record: 622 of 635 |  Shalakusha
# Processing Record: 623 of 635 |  Imbituba
# Processing Record: 624 of 635 |  Lampa
# Processing Record: 625 of 635 |  Xining
# Processing Record: 626 of 635 |  Mayo
# Processing Record: 627 of 635 |  Baillif
# Processing Record: 628 of 635 |  Vinh
# Processing Record: 629 of 635 |  Atar
# Processing Record: 630 of 635 |  Ketchikan
# City not found. Skipping
# Processing Record: 632 of 635 |  Silvan
# Processing Record: 633 of 635 |  Kajiado
# Processing Record: 634 of 635 |  Moussoro
# Processing Record: 635 of 635 |  General Roca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# creating dictionary
weather_dict = {
    "City": city1,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lon,
    #"Temp": temp,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# %%
# diplaying dataframe
weather_pd = pd.DataFrame(weather_dict)
weather_pd.head()
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Saskylakh          22      RU  1563513817        37  71.97  114.09
# 1  Barao de Melgaco           0      BR  1563513817        64 -16.19  -55.97
# 2            Albany          90      US  1563513816        78  42.65  -73.75
# 3          Hamilton          20      CA  1563513737       100  43.26  -79.87
# 4       Tuktoyaktuk           5      CA  1563513817        82  69.44 -133.03
#
#    Max Temp  Wind Speed
# 0     17.58        3.36
# 1     24.00        1.00
# 2     22.00        2.10
# 3     25.00        2.60
# 4     14.00        4.10

# %%
print(weather_pd.count())
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Lat           571
# Lng           571
# Max Temp      571
# Wind Speed    571
# dtype: int64

# %%
# saving data to csv
weather_pd.to_csv(
    "weather_dataframe.csv", encoding="utf-8", index=False)

# %%
# Reading CSV file
weather_data_original = pd.read_csv(
    "weather_dataframe.csv", dtype="object", encoding="utf-8")

# Visualize
weather_data_original.head()
# Out:
#                City Cloudiness Country        Date Humidity     Lat      Lng  \
# 0         Saskylakh         22      RU  1563513817       37   71.97   114.09
# 1  Barao de Melgaco          0      BR  1563513817       64  -16.19   -55.97
# 2            Albany         90      US  1563513816       78   42.65   -73.75
# 3          Hamilton         20      CA  1563513737      100   43.26   -79.87
# 4       Tuktoyaktuk          5      CA  1563513817       82   69.44  -133.03
#
#   Max Temp Wind Speed
# 0    17.58       3.36
# 1     24.0        1.0
# 2     22.0        2.1
# 3     25.0        2.6
# 4     14.0        4.1

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# obtaining max/min values
lat_max = weather_pd["Lat"].max()
lat_min = weather_pd["Lat"].min()
maxt_max = weather_pd["Max Temp"].max()
maxt_min = weather_pd["Max Temp"].min()

 # for degF and mph, units must be either changed to "imperial" or converted manually as a calculated variable
print(f'Maximum latitude = {lat_max}')
print(f'Minimum latitude = {lat_min}')
print(f'Max Maximum temperature = {maxt_max} degC')
print(f'Min Maximum temperature = {maxt_min} degC')
# Out:
# Maximum latitude = 78.22
# Minimum latitude = -54.81
# Max Maximum temperature = 42.58 degC
# Min Maximum temperature = -1.11 degC

# %%
# Build a scatter plot for each data type
plt.scatter(x=weather_pd["Lat"], y=weather_pd["Max Temp"], marker="o", alpha=0.7, 
            edgecolors="black", facecolors="skyblue")

# Incorporate the other graph properties
plt.ylim((maxt_min,maxt_max+1))
plt.xlim((lat_min,lat_max+1))
plt.yticks(np.arange(-5,45+1, 10.0))
plt.xticks(np.arange(-60,90+1, 20.0))
plt.grid(True)

plt.title("City Latitude vs. Max Temperature (07/18/2019)")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("MaxTemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(x=weather_pd["Lat"], y=weather_pd["Humidity"], marker="o", alpha=0.7, 
            edgecolors="black", facecolors="skyblue")

# Incorporate the other graph properties

plt.ylim((0,100+1)) #from 0-100 %
plt.xlim((lat_min,lat_max+1))
plt.yticks(np.arange(0,100+1, 10.0))
plt.xticks(np.arange(-60,90+1, 20.0))
plt.grid(True)

plt.title("City Latitude vs. Humidity (07/18/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(x=weather_pd["Lat"], y=weather_pd["Cloudiness"], marker="o", alpha=0.7, 
            edgecolors="black", facecolors="skyblue")

# Incorporate the other graph properties

plt.ylim((0,100+1))  #from 0-100 %
plt.xlim((lat_min,lat_max+1))
plt.yticks(np.arange(0,100+1, 10.0))
plt.xticks(np.arange(-60,90+1, 20.0))
plt.grid(True)

plt.title("City Latitude vs. Cloudiness (07/18/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Obtaining max/min wind speed
ws_max = weather_pd["Wind Speed"].max()
ws_min = weather_pd["Wind Speed"].min()

print(f'Maximum speed = {ws_max} m/s')
print(f'Minimum speed = {ws_min} m/s')
# Out:
# Maximum speed = 16.65 m/s
# Minimum speed = 0.1 m/s

# %%
# Build a scatter plot for each data type
plt.scatter(x=weather_pd["Lat"], y=weather_pd["Wind Speed"], marker="o", alpha=0.7, 
            edgecolors="black", facecolors="skyblue")

# Incorporate the other graph properties
#x = [-60,80]

plt.ylim((ws_min,ws_max+1))
plt.xlim((lat_min,lat_max+1))
plt.yticks(np.arange(0,18+1, 2.0))
plt.xticks(np.arange(-60,90+1, 20.0))
plt.grid(True)



plt.title("City Latitude vs. Wind Speed (07/18/2019)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("WindSpeedInWorldCities.png")

# Show plot
plt.show()
